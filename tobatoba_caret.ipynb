# %% [markdown]
# # データ

# %% [markdown]
# ## adapi

# %%
adapi_node_autoware_state = [
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-autoware_state-callback_0.npy"
]
adapi_node_fail_safe = [
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-fail_safe-callback_0.npy",
]

adapi_node_heartbeat= [
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-heartbeat-callback_0.npy",
]
adapi_node_motion= [
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-motion-callback_0.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-motion-callback_1.npy",
]
adapi_node_operation_mode= [
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-operation_mode-callback_0.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-operation_mode-callback_2.npy",
]
adapi_node_perception= [
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-perception-callback_0.npy",
]
adapi_node_planning= [
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_00.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_01.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_02.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_03.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_04.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_05.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_06.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_07.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_08.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_12.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_13.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_17.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_19.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_21.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_22.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_23.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_24.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_25.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_26.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-planning-callback_27.npy",
]
adapi_node_vehicle= [
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-vehicle-callback_0.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-vehicle-callback_1.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-vehicle-callback_2.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-vehicle-callback_3.npy",
    "/home/yutaro/wd/multi-rate_simulator/merged_latencies/-adapi-node-vehicle-callback_4.npy"
]


adapis =[
    adapi_node_autoware_state,
    adapi_node_fail_safe,
    adapi_node_heartbeat,
    adapi_node_motion,
    adapi_node_operation_mode,
    adapi_node_perception,
    adapi_node_planning,
    adapi_node_vehicle
]

# %% [markdown]
# ## Control

# %%
import glob
import os

directory_A = "/home/yutaro/wd/multi-rate_simulator/merged_latencies"  # ディレクトリAのパス
file_pattern = "-control-*"

file_paths = glob.glob(f"{directory_A}/{file_pattern}")

# ファイル名の共通部分を除去し、ファイルを整理
files = []

for file in file_paths:
    filename = os.path.basename(file)
    
    # "-control-" 以降の部分を取得（"-callback_" より前の部分を取得）
    parts = filename.split("-callback_")
    if len(parts) > 1:
        callback_part = parts[1]  # "-callback_0.npy" のような部分を取得
        files.append(f"'{filename}'")

# 一列で表示
print(", ".join(files))

print(f"Total files: {len(file_paths)}")
# Out:
# '-control-autonomous_emergency_braking-callback_1.npy', '-control-collision_detector-callback_1.npy', '-control-vehicle_cmd_gate-callback_14.npy', '-control-autoware_operation_mode_transition_manager-callback_7.npy', '-control-vehicle_cmd_gate-callback_00.npy', '-control-autoware_operation_mode_transition_manager-callback_5.npy', '-control-vehicle_cmd_gate-callback_11.npy', '-control-external_cmd_converter-callback_1.npy', '-control-vehicle_cmd_gate-callback_16.npy', '-control-autonomous_emergency_braking-callback_0.npy', '-control-control_validator-callback_1.npy', '-control-trajectory_follower-lane_departure_checker_node-callback_0.npy', '-control-trajectory_follower-lane_departure_checker_node-callback_1.npy', '-control-external_cmd_converter-callback_0.npy', '-control-vehicle_cmd_gate-callback_21.npy', '-control-vehicle_cmd_gate-callback_15.npy', '-control-control_evaluator-callback_0.npy', '-control-trajectory_follower-controller_node_exe-callback_0.npy', '-control-autoware_oper
# ...

# %%
import glob

directory_A = "/home/yutaro/wd/multi-rate_simulator/merged_latencies"  # ディレクトリAのパス
file_pattern = "-control-*"

file_paths = glob.glob(f"{directory_A}/{file_pattern}")
file_paths = sorted(file_paths)

for file in file_paths:
    print(str("'")+file+str("',"))  # 取得したファイルのパスを表示
print(len(file_paths))  # 取得したファイルの数を表示
# Out:
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autonomous_emergency_braking-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autonomous_emergency_braking-callback_1.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_3.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_4.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_5.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_6.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_7.npy',
# ...

# %%
control_autonomous_emergency_braking = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autonomous_emergency_braking-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autonomous_emergency_braking-callback_1.npy',
]
control_autoware_operation_mode_transition_manager = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_3.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_4.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_5.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_6.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_7.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_operation_mode_transition_manager-callback_8.npy',
]
control_shift_decider = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-autoware_shift_decider-callback_0.npy',
]
control_collision_detector = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-collision_detector-callback_1.npy',
]
control_control_evaluator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-control_evaluator-callback_0.npy',
]
control_control_validator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-control_validator-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-control_validator-callback_1.npy',
]
control_external_cmd_converter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-external_cmd_converter-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-external_cmd_converter-callback_1.npy',
]
control_external_cmd_selector =[
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-external_cmd_selector-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-external_cmd_selector-callback_1.npy',
]
control_trajectory_follower = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-trajectory_follower-controller_node_exe-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-trajectory_follower-controller_node_exe-callback_1.npy',
]
control_trajectory_follower_lane_departure_checker = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-trajectory_follower-lane_departure_checker_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-trajectory_follower-lane_departure_checker_node-callback_1.npy',
]
control_vehicle_cmd_gate = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_00.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_01.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_02.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_11.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_14.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_15.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_16.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_18.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_19.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-control-vehicle_cmd_gate-callback_21.npy',
]

controls = [
    control_autonomous_emergency_braking,
    control_autoware_operation_mode_transition_manager,
    control_shift_decider,
    control_collision_detector,
    control_control_evaluator,
    control_control_validator,
    control_external_cmd_converter,
    control_external_cmd_selector,
    control_trajectory_follower,
    control_trajectory_follower_lane_departure_checker,
    control_vehicle_cmd_gate
]

# %% [markdown]
# ### default_adpiは飛ばす

# %% [markdown]
# ## localization

# %%
import glob

directory_A = "/home/yutaro/wd/multi-rate_simulator/merged_latencies"  # ディレクトリAのパス
file_pattern = "-localization-*"

file_paths = glob.glob(f"{directory_A}/{file_pattern}")
file_paths = sorted(file_paths)

for file in file_paths:
    print(str("'")+file+str("',"))  # 取得したファイルのパスを表示
print(len(file_paths))  # 取得したファイルの数を表示
# Out:
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-localization_error_monitor-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_estimator-ndt_scan_matcher-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_estimator-ndt_scan_matcher-callback_1.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_estimator-ndt_scan_matcher-callback_2.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-ekf_localizer-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-ekf_localizer-callback_1.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-ekf_localizer-callback_2.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-pose_instability_detector-callback_0.npy',
# ...

# %%
local_localization_error_monitor = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-localization_error_monitor-callback_0.npy',
]
local_ndt_scan_matcher = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_estimator-ndt_scan_matcher-callback_0.npy',
]
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_estimator-ndt_scan_matcher-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_estimator-ndt_scan_matcher-callback_2.npy',
local_ekf_localizer = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-ekf_localizer-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-ekf_localizer-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-ekf_localizer-callback_2.npy',
]
local_pose_instability_detector = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-pose_instability_detector-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-pose_instability_detector-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-pose_instability_detector-callback_2.npy',
]
local_stop_filter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-stop_filter-callback_0.npy',
]
local_twist2accel = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-twist2accel-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-pose_twist_fusion_filter-twist2accel-callback_1.npy',
]
local_gyro_odometer = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-twist_estimator-gyro_odometer-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-twist_estimator-gyro_odometer-callback_1.npy',
]
local_crop_box_filter_measurement_range = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-util-crop_box_filter_measurement_range-callback_0.npy',
]
local_autoware_automatic_pose_initializer = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-util-default_adapi-helpers-autoware_automatic_pose_initializer-callback_0.npy',
]
local_pose_initializer = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-util-pose_initializer-callback_0.npy',
]
local_random_downsample_filter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-util-random_downsample_filter-callback_0.npy',
]
local_voxel_grid_downsample_filter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-localization-util-voxel_grid_downsample_filter-callback_0.npy',
]

locals = [
    local_localization_error_monitor,
    local_twist2accel,
    local_ndt_scan_matcher,
    local_ekf_localizer,
    local_pose_instability_detector,
    local_stop_filter,
    local_gyro_odometer,
    local_crop_box_filter_measurement_range,
    local_autoware_automatic_pose_initializer,
    local_pose_initializer,
    local_random_downsample_filter,
    local_voxel_grid_downsample_filter
]

# %% [markdown]
# ## perception

# %%
import glob

directory_A = "/home/yutaro/wd/multi-rate_simulator/merged_latencies"  # ディレクトリAのパス
file_pattern = "-perception-*"

file_paths = glob.glob(f"{directory_A}/{file_pattern}")
file_paths = sorted(file_paths)

for file in file_paths:
    print(str("'")+file+str("',"))  # 取得したファイルのパスを表示
print(len(file_paths))  # 取得したファイルの数を表示
# Out:
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-centerpoint-lidar_centerpoint-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-detected_object_feature_remover-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-euclidean_cluster-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-shape_estimation-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-detection_by_tracker-detection_by_tracker_node-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-detection_by_tracker-detection_by_tracker_node-callback_1.npy',
# ...

# %%
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-centerpoint-lidar_centerpoint-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-detected_object_feature_remover-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-euclidean_cluster-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-shape_estimation-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-detection_by_tracker-detection_by_tracker_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-detection_by_tracker-detection_by_tracker_node-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_association_merger_alpha-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_association_merger_alpha-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_association_merger_beta-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_association_merger_beta-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_lanelet_filter-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-obstacle_pointcloud_based_validator_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-obstacle_pointcloud_based_validator_node-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-voxel_based_compare_map_filter-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-voxel_grid_downsample_filter-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-prediction-map_based_prediction-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-tracking-multi_object_tracker-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-tracking-multi_object_tracker-callback_2.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-tracking-multi_object_tracker-callback_3.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-obstacle_segmentation-common_ground_filter-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-obstacle_segmentation-crop_box_filter-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-obstacle_segmentation-occupancy_grid_based_outlier_filter-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-obstacle_segmentation-occupancy_grid_based_outlier_filter-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-occupancy_grid_map-occupancy_grid_map_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-occupancy_grid_map-occupancy_grid_map_node-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-classification-car_traffic_light_classifier-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-classification-pedestrian_traffic_light_classifier-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-classification-traffic_light_occlusion_predictor-callback_05.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-classification-traffic_light_occlusion_predictor-callback_09.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-detection-traffic_light_fine_detector-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-traffic_light_camera_info_relay-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-traffic_light_roi_visualizer-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-classification-car_traffic_light_classifier-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-classification-pedestrian_traffic_light_classifier-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-classification-traffic_light_occlusion_predictor-callback_05.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-classification-traffic_light_occlusion_predictor-callback_09.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-detection-traffic_light_fine_detector-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-traffic_light_camera_info_relay-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-traffic_light_roi_visualizer-callback_0.npy',
# Out:
# ('/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-traffic_light_roi_visualizer-callback_0.npy',)

# %%
perception_lidar_centerpoint = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-centerpoint-lidar_centerpoint-callback_0.npy',
]
                                                                    
perception_detected_object_feature_remover = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-detected_object_feature_remover-callback_0.npy',
]                                                                 
                                                         
perception_euclidean_cluster = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-euclidean_cluster-callback_0.npy',
]                           
                                                       
perception_shape_estimation = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-clustering-shape_estimation-callback_0.npy',
]
                                                                   
perception_detection_by_tracker_node = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-detection_by_tracker-detection_by_tracker_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-detection_by_tracker-detection_by_tracker_node-callback_1.npy',
]                                                   
                                                    
perception_object_association_merger_alpha = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_association_merger_alpha-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_association_merger_alpha-callback_1.npy',
]                      

perception_object_association_merger_beta = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_association_merger_beta-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_association_merger_beta-callback_1.npy',
]
                                                                  
perception_object_lanelet_filter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-object_lanelet_filter-callback_0.npy',
]                                                  
                                                           
perception_obstacle_pointcloud_based_validator_node = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-obstacle_pointcloud_based_validator_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-obstacle_pointcloud_based_validator_node-callback_1.npy',
]                                           
                                                                   
perception_voxel_based_compare_map_filter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-voxel_based_compare_map_filter-callback_0.npy',
]                                                   
                                                                  
perception_voxel_grid_downsample_filter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-detection-voxel_grid_downsample_filter-callback_0.npy',
]                                    
                                                                   
perception_map_based_prediction = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-prediction-map_based_prediction-callback_1.npy',
]                                     
                                                                   
perception_multi_object_tracker = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-tracking-multi_object_tracker-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-tracking-multi_object_tracker-callback_2.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-object_recognition-tracking-multi_object_tracker-callback_3.npy',
]                                                   
                                                                   
perception_common_ground_filter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-obstacle_segmentation-common_ground_filter-callback_0.npy',
]
perception_crop_box_filter = [                                                
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-obstacle_segmentation-crop_box_filter-callback_0.npy',
]
perception_occupancy_grid_based_outlier_filter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-obstacle_segmentation-occupancy_grid_based_outlier_filter-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-obstacle_segmentation-occupancy_grid_based_outlier_filter-callback_1.npy',
]
perception_occupancy_grid_map_node = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-occupancy_grid_map-occupancy_grid_map_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-occupancy_grid_map-occupancy_grid_map_node-callback_1.npy',
]
perception_car_traffic_light_classifier_6 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-classification-car_traffic_light_classifier-callback_0.npy',
]
perception_pedestrian_traffic_light_classifier_6 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-classification-pedestrian_traffic_light_classifier-callback_0.npy',
]
perception_traffic_light_occlusion_predictor_6 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-classification-traffic_light_occlusion_predictor-callback_05.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-classification-traffic_light_occlusion_predictor-callback_09.npy',
]

perception_traffic_light_fine_detector_6 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-detection-traffic_light_fine_detector-callback_0.npy',
]

perception_traffic_light_camera_info_relay_6 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-traffic_light_camera_info_relay-callback_0.npy',
]
perception_traffic_light_roi_visualizer_6 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera6-traffic_light_roi_visualizer-callback_0.npy',
]
perception_car_traffic_light_classifier_7 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-classification-car_traffic_light_classifier-callback_0.npy',
]
perception_pedestrian_traffic_light_classifier_7 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-classification-pedestrian_traffic_light_classifier-callback_0.npy',
]
perception_traffic_light_occlusion_predictor_7 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-classification-traffic_light_occlusion_predictor-callback_05.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-classification-traffic_light_occlusion_predictor-callback_09.npy',
]
perception_traffic_light_fine_detector_7 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-detection-traffic_light_fine_detector-callback_0.npy',
]
perception_traffic_light_camera_info_relay_7 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-traffic_light_camera_info_relay-callback_0.npy',
]
perception_traffic_light_roi_visualizer_7 = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-perception-traffic_light_recognition-camera7-traffic_light_roi_visualizer-callback_0.npy',
]

perceptions = [
    perception_lidar_centerpoint,
    perception_detected_object_feature_remover,
    perception_euclidean_cluster,
    perception_shape_estimation,
    perception_detection_by_tracker_node,
    perception_object_association_merger_alpha,
    perception_object_association_merger_beta,
    perception_object_lanelet_filter,
    perception_obstacle_pointcloud_based_validator_node,
    perception_voxel_based_compare_map_filter,
    perception_voxel_grid_downsample_filter,
    perception_map_based_prediction,
    perception_multi_object_tracker,
    perception_common_ground_filter,
    perception_crop_box_filter,
    perception_occupancy_grid_based_outlier_filter,
    perception_occupancy_grid_map_node,
    perception_car_traffic_light_classifier_6,
    perception_pedestrian_traffic_light_classifier_6,
    perception_traffic_light_occlusion_predictor_6,
    perception_traffic_light_fine_detector_6,
    perception_traffic_light_camera_info_relay_6,
    perception_traffic_light_roi_visualizer_6,
    perception_car_traffic_light_classifier_7,
    perception_pedestrian_traffic_light_classifier_7,
    perception_traffic_light_occlusion_predictor_7,
    perception_traffic_light_fine_detector_7,
    perception_traffic_light_camera_info_relay_7,
    perception_traffic_light_roi_visualizer_7
]

# %% [markdown]
# ## planning

# %%
import glob

directory_A = "/home/yutaro/wd/multi-rate_simulator/merged_latencies"  # ディレクトリAのパス
file_pattern = "-planning-*"

file_paths = glob.glob(f"{directory_A}/{file_pattern}")
file_paths = sorted(file_paths)

for file in file_paths:
    print(str("'")+file+str("',"))  # 取得したファイルのパスを表示
print(len(file_paths))  # 取得したファイルの数を表示
# Out:
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-mission_planning-mission_planner-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-mission_planning-mission_planner-callback_1.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-mission_planning-mission_planner-callback_3.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-planning_evaluator-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-planning_validator-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-planning_validator-callback_2.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-remaining_distance_time_calculator-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-remaining_distance_time_calculator-callback_1.npy',
# ...

# %%
plannning_mission_planner = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-mission_planning-mission_planner-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-mission_planning-mission_planner-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-mission_planning-mission_planner-callback_3.npy',
]


plannning_planning_evaluator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-planning_evaluator-callback_0.npy',
]

plannning_planning_validator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-planning_validator-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-planning_validator-callback_2.npy',
]

plannning_remaining_distance_time_calculator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-remaining_distance_time_calculator-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-remaining_distance_time_calculator-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-remaining_distance_time_calculator-callback_4.npy',
]

plannning_behavior_path_planner = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_00.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_01.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_02.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_03.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_04.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_05.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_06.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_07.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_08.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_09.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_10.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_path_planner-callback_11.npy',
]

plannning_behavior_velocity_planner = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_velocity_planner-callback_00.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_velocity_planner-callback_01.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_velocity_planner-callback_02.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_velocity_planner-callback_03.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_velocity_planner-callback_04.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_velocity_planner-callback_05.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-behavior_planning-behavior_velocity_planner-callback_13.npy',
]

plannning_elastic_band_smoother = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-motion_planning-elastic_band_smoother-callback_1.npy',
]

plannning_motion_velocity_planner = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-motion_planning-motion_velocity_planner-callback_6.npy',
]

plannning_obstacle_stop_relay = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-motion_planning-obstacle_stop_relay-callback_0.npy',
]

plannning_path_optimizer = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-lane_driving-motion_planning-path_optimizer-callback_1.npy',
]

plannning_costmap_generator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-parking-costmap_generator-callback_0.npy',
]

plannning_freespace_planner = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-parking-freespace_planner-callback_0.npy',
]

plannning_scenario_selector = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-scenario_selector-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-scenario_selector-callback_1.npy',
]

plannning_velocity_smoother = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-planning-scenario_planning-velocity_smoother-callback_4.npy',
]

plannings = [
    plannning_mission_planner,
    plannning_planning_evaluator,
    plannning_planning_validator,
    plannning_remaining_distance_time_calculator,
    plannning_behavior_path_planner,
    plannning_behavior_velocity_planner,
    plannning_elastic_band_smoother,
    plannning_motion_velocity_planner,
    plannning_obstacle_stop_relay,
    plannning_path_optimizer,
    plannning_costmap_generator,
    plannning_freespace_planner,
    plannning_scenario_selector,
    plannning_velocity_smoother
]

# %% [markdown]
# ## sensing

# %%
directory_A = "/home/yutaro/wd/multi-rate_simulator/merged_latencies"  # ディレクトリAのパス
file_pattern = "-sensing-*"

file_paths = glob.glob(f"{directory_A}/{file_pattern}")
file_paths = sorted(file_paths)

for file in file_paths:
    print(str("'")+file+str("',"))  # 取得したファイルのパスを表示
print(len(file_paths))  # 取得したファイルの数を表示
# Out:
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-gnss-gnss_poser-callback_1.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-gyro_bias_validator-callback_1.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-gyro_bias_validator-callback_2.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-gyro_bias_validator-callback_3.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-gyro_bias_validator-callback_4.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-imu_corrector-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_000.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_294.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_295.npy',
# ...

# %%
sensing_gnss_poser = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-gnss-gnss_poser-callback_1.npy',
]

sensing_gyro_bias_validator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-gyro_bias_validator-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-gyro_bias_validator-callback_2.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-gyro_bias_validator-callback_3.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-gyro_bias_validator-callback_4.npy',
]


sensing_imu_corrector = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-imu-imu_corrector-callback_0.npy',
]

sensing_concatenate_data = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_000.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_294.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_295.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_296.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_297.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_298.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_299.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_300.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_301.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_302.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_303.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_304.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-concatenate_data-callback_305.npy',
]

sensing_crop_box_filter_mirror_left = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-left-crop_box_filter_mirror-callback_0.npy',
]

sensing_crop_box_filter_self_left = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-left-crop_box_filter_self-callback_0.npy',
]

sensing_distortion_corrector_node_left = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-left-distortion_corrector_node-callback_2.npy',
]

sensing_ring_outlier_filter_left = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-left-ring_outlier_filter-callback_0.npy',
]

sensing_velodyne_ros_wrapper_node_left = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-left-velodyne_ros_wrapper_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-left-velodyne_ros_wrapper_node-callback_1.npy',
]

sensing_velodyne_ros_wrapper_node_rear = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-rear-velodyne_ros_wrapper_node-callback_0.npy',
]
sensing_crop_box_filter_mirror_right = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-right-crop_box_filter_mirror-callback_0.npy',
]
sensing_crop_box_filter_self_right = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-right-crop_box_filter_self-callback_0.npy',
]
sensing_distortion_corrector_node_right = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-right-distortion_corrector_node-callback_2.npy',
]
sensing_ring_outlier_filter_right = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-right-ring_outlier_filter-callback_0.npy',
]
sensing_velodyne_ros_wrapper_node_right = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-right-velodyne_ros_wrapper_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-right-velodyne_ros_wrapper_node-callback_1.npy',
]

sensing_crop_box_filter_mirror_top = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-top-crop_box_filter_mirror-callback_0.npy',
]

sensing_crop_box_filter_self_top = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-top-crop_box_filter_self-callback_0.npy',
]

sensing_distortion_corrector_node_top = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-top-distortion_corrector_node-callback_2.npy',
]

sensing_ring_outlier_filter_top = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-top-ring_outlier_filter-callback_0.npy',
]

sensing_velodyne_ros_wrapper_node_top = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-top-velodyne_ros_wrapper_node-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-lidar-top-velodyne_ros_wrapper_node-callback_1.npy',
]

sensing_vehicle_velocity_converter = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-sensing-vehicle_velocity_converter-callback_0.npy',
]


sensings = [
    sensing_gnss_poser,
    sensing_gyro_bias_validator,
    sensing_imu_corrector,
    sensing_concatenate_data,
    sensing_crop_box_filter_mirror_left,
    sensing_crop_box_filter_self_left,
    sensing_distortion_corrector_node_left,
    sensing_ring_outlier_filter_left,
    sensing_velodyne_ros_wrapper_node_left,
    sensing_velodyne_ros_wrapper_node_rear,
    sensing_crop_box_filter_mirror_right,
    sensing_crop_box_filter_self_right,
    sensing_distortion_corrector_node_right,
    sensing_ring_outlier_filter_right,
    sensing_velodyne_ros_wrapper_node_right,
    sensing_crop_box_filter_mirror_top,
    sensing_crop_box_filter_self_top,
    sensing_distortion_corrector_node_top,
    sensing_ring_outlier_filter_top,
    sensing_velodyne_ros_wrapper_node_top,
    sensing_vehicle_velocity_converter
]

# %% [markdown]
# ## system

# %%
directory_A = "/home/yutaro/wd/multi-rate_simulator/merged_latencies"  # ディレクトリAのパス
file_pattern = "-system-*"

file_paths = glob.glob(f"{directory_A}/{file_pattern}")
file_paths = sorted(file_paths)

for file in file_paths:
    print(str("'")+file+str("',"))  # 取得したファイルのパスを表示
print(len(file_paths))  # 取得したファイルの数を表示
# Out:
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-aggregator-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-component_state_monitor-component-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-duplicated_node_checker-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-duplicated_node_checker-callback_1.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_comfortable_stop_operator-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_emergency_stop_operator-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_emergency_stop_operator-callback_1.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_handler-callback_0.npy',
# '/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_handler-callback_7.npy',
# ...

# %%
system_aggregator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-aggregator-callback_0.npy',
]

system_component_state_monitor = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-component_state_monitor-component-callback_0.npy',
]

system_duplicated_node_checker = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-duplicated_node_checker-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-duplicated_node_checker-callback_1.npy',
]

system_mrm_comfortable_stop_operator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_comfortable_stop_operator-callback_0.npy',
]

system_mrm_emergency_stop_operator = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_emergency_stop_operator-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_emergency_stop_operator-callback_1.npy',
]

system_mrm_handler = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_handler-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-mrm_handler-callback_7.npy',
]

system_processing_time_checker = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_00.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_01.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_02.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_03.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_04.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_05.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_06.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_07.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_10.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_11.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_12.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_13.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_14.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_15.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_16.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_18.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_19.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_20.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-processing_time_checker-callback_21.npy',
]


system_service_log_checker = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-service_log_checker-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-service_log_checker-callback_1.npy',
]


system_topic_state_monitor_control_command_control_cmd = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_control_command_control_cmd-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_control_command_control_cmd-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_control_command_control_cmd-callback_2.npy',
]

system_topic_state_monitor_initialpose3d = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_initialpose3d-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_initialpose3d-callback_1.npy',
]

system_topic_state_monitor_mission_planning_route = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_mission_planning_route-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_mission_planning_route-callback_1.npy',
]

system_topic_state_monitor_object_recognition_objects = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_object_recognition_objects-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_object_recognition_objects-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_object_recognition_objects-callback_2.npy',
]

system_topic_state_monitor_obstacle_segmentation_pointcloud = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_obstacle_segmentation_pointcloud-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_obstacle_segmentation_pointcloud-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_obstacle_segmentation_pointcloud-callback_2.npy',
]

system_topic_state_monitor_pointcloud_map = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_pointcloud_map-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_pointcloud_map-callback_1.npy',
]

system_topic_state_monitor_pose_twist_fusion_filter_pose = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_pose_twist_fusion_filter_pose-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_pose_twist_fusion_filter_pose-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_pose_twist_fusion_filter_pose-callback_2.npy',
]

system_topic_state_monitor_scenario_planning_trajectory = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_scenario_planning_trajectory-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_scenario_planning_trajectory-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_scenario_planning_trajectory-callback_2.npy',
]

system_topic_state_monitor_system_emergency_control_cmd = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_system_emergency_control_cmd-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_system_emergency_control_cmd-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_system_emergency_control_cmd-callback_2.npy',
]

system_topic_state_monitor_traffic_light_recognition_traffic_signals = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_traffic_light_recognition_traffic_signals-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_traffic_light_recognition_traffic_signals-callback_1.npy',
]

system_topic_state_monitor_trajectory_follower_control_cmd = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_trajectory_follower_control_cmd-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_trajectory_follower_control_cmd-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_trajectory_follower_control_cmd-callback_2.npy',
]

system_topic_state_monitor_transform_map_to_base_link = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_transform_map_to_base_link-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_transform_map_to_base_link-callback_1.npy',
]

system_topic_state_monitor_vector_map = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_vector_map-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_vector_map-callback_1.npy',
]

system_topic_state_monitor_vehicle_status_steering_status = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_vehicle_status_steering_status-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_vehicle_status_steering_status-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_vehicle_status_steering_status-callback_2.npy',
]

system_topic_state_monitor_vehicle_status_velocity_status = [
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_vehicle_status_velocity_status-callback_0.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_vehicle_status_velocity_status-callback_1.npy',
'/home/yutaro/wd/multi-rate_simulator/merged_latencies/-system-topic_state_monitor_vehicle_status_velocity_status-callback_2.npy',
]

systems = [
    system_aggregator,
    system_component_state_monitor,
    system_duplicated_node_checker,
    system_mrm_comfortable_stop_operator,
    system_mrm_emergency_stop_operator,
    system_mrm_handler,
    system_processing_time_checker,
    system_service_log_checker,
    system_topic_state_monitor_control_command_control_cmd,
    system_topic_state_monitor_initialpose3d,
    system_topic_state_monitor_mission_planning_route,
    system_topic_state_monitor_object_recognition_objects,
    system_topic_state_monitor_obstacle_segmentation_pointcloud,
    system_topic_state_monitor_pointcloud_map,
    system_topic_state_monitor_pose_twist_fusion_filter_pose,
    system_topic_state_monitor_scenario_planning_trajectory,
    system_topic_state_monitor_system_emergency_control_cmd,
    system_topic_state_monitor_traffic_light_recognition_traffic_signals,
    system_topic_state_monitor_trajectory_follower_control_cmd,
    system_topic_state_monitor_transform_map_to_base_link,
    system_topic_state_monitor_vector_map,
    system_topic_state_monitor_vehicle_status_steering_status,
    system_topic_state_monitor_vehicle_status_velocity_status,
]

# %%
import numpy as np

# components = [
#     adapis,
#     controls,
#     perceptions,
#     plannings,
#     sensings,
#     systems,
# ]

components = [ 
    controls
]

base_path = "/home/yutaro/wd/multi-rate_simulator/merged_latencies/"

for comp in components:
    for node_paths in comp:
        max_latency = 0
        max_name = ""
        for node_path in node_paths:
            array = np.load(node_path)
            array_max = np.max(array)
            if array_max > max_latency:
                max_latency = array_max
                max_name = node_path
        max_name = max_name.replace(base_path, "")
        print(max_name)
        with open('max_latency.txt', 'a') as f:
            f.write(f"{max_name}, {max_latency}\n")
# Out:
# -control-autonomous_emergency_braking-callback_1.npy
# -control-autoware_operation_mode_transition_manager-callback_0.npy
# -control-autoware_shift_decider-callback_0.npy
# -control-collision_detector-callback_1.npy
# -control-control_evaluator-callback_0.npy
# -control-control_validator-callback_0.npy
# -control-external_cmd_converter-callback_0.npy
# -control-external_cmd_selector-callback_1.npy
# -control-trajectory_follower-controller_node_exe-callback_1.npy
# -control-trajectory_follower-lane_departure_checker_node-callback_1.npy
# -control-vehicle_cmd_gate-callback_01.npy
